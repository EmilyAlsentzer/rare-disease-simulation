# %% [markdown]
# We provide all of the files to run this script (except the raw claims data) as well as the files that are generated from running this script in the Harvard Dataverse repo. Note that you may need to run the `Orphanet Convert to Flat Files.ipynb` first before running this script.

# %%
import pandas as pd
import numpy as np
import sys
import obonet
import networkx
import config
import logging
import seaborn as sns
import matplotlib.pyplot as plt

from simulation_pipeline.utils import preprocess 

sys.path.insert(0, '../') # add config to path

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Read in data

# %%
#Path to raw phenolyzer data
PHENOLYZER_LIB = config.KNOWLEDGE_GRAPH_PATH / 'raw_phenolyzer_2015'

PHENOLYZER_2015_OUTPUT_DIR = config.KNOWLEDGE_GRAPH_PATH / 'raw_normalized_phenolyzer_2015'

# %%
# 2015 KG
hpoa_phen_genes_2015 = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_HPO_PHENOTYPE_GENE', sep='\t', header=None)
hpoa_phen_genes_2015.columns = ['HPO_ID', 'HPO_NAME', 'GENE_LIST']
hpoa_phen_genes_2015['GENE_LIST'] = hpoa_phen_genes_2015['GENE_LIST'].str.replace(',$', '')
hpoa_phen_genes_2015['GENE_LIST'] = hpoa_phen_genes_2015['GENE_LIST'].str.replace('^,', '')
hpoa_phen_genes_2015['GENE_LIST'] = hpoa_phen_genes_2015['GENE_LIST'].str.split(',')
hpoa_phen_genes_2015 = hpoa_phen_genes_2015.explode('GENE_LIST')

hpoa_phen_diseases_2015 = pd.read_csv(PHENOLYZER_LIB / 'DB_HPO_ANNOTATION', sep='\t', dtype=str)
hpoa_phen_diseases_2015['HPO_ID'] = 'HP:' + hpoa_phen_diseases_2015['HPO_ID']

coba = pd.read_csv(PHENOLYZER_LIB / 'DB_COBA_NEUROCOMPLEX', sep='\t', dtype=str, header=None)
coba.columns = ['GENE_ID', 'DISEASE', 'SOURCE', 'SCORE', 'CATEGORY']

protein_interaction = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_BINARY_PROTEIN_INTERACTION_SCORE', sep='\t', dtype=str)
biosystem = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_BIOSYSTEM_SCORE', sep='\t', dtype=str)
gene_reviews = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_GENEREVIEWS', sep='\t', dtype=str)
gene_dx = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_GENE_DISEASE_SCORE', sep='\t', dtype=str)
gene_dx['GENE'] = gene_dx['GENE'].str.replace(',$', '')
gene_dx['GENE'] = gene_dx['GENE'].str.replace('^,', '')
gene_dx['GENE'] = gene_dx['GENE'].str.split(',')
gene_dx = gene_dx.explode('GENE')

disgenet = pd.read_csv(PHENOLYZER_LIB / 'DB_DISGENET_GENE_DISEASE_SCORE', sep='\t', dtype=str, header=None)
disgenet.columns = ['GENE_ID', 'DISEASE', 'DISEASE_ID', 'SCORE', 'SOURCE']
gad = pd.read_csv(PHENOLYZER_LIB / 'DB_GAD_GENE_DISEASE_SCORE', sep='\t', dtype=str, header=None)
gad.columns = ['GENE_ID', 'DISEASE', 'DISEASE_PUBMED', 'SCORE', 'SOURCE']

genecards = pd.read_csv(PHENOLYZER_LIB / 'DB_GENECARDS_GENE_DISEASE_SCORE', sep='\t', dtype=str, header=None)
genecards.columns = ['GENE_ID', 'DISEASE', 'UNK', 'SCORE', 'SOURCE']
hgnc = pd.read_csv(PHENOLYZER_LIB / 'DB_HGNC_GENE_FAMILY', sep='\t', dtype=str)
transcription = pd.read_csv(PHENOLYZER_LIB / 'DB_HTRI_TRANSCRIPTION_INTERACTION', sep='\t', dtype=str)

human_gene_id = pd.read_csv(PHENOLYZER_LIB / 'DB_HUMAN_GENE_ID', sep='\t', dtype=str, skiprows=1, header=None)
human_gene_id.columns= ['', 'GENE_ID', 'GENE_LIST']
human_gene_id['GENE_LIST'] = human_gene_id['GENE_LIST'].str.replace('|$', '')
human_gene_id['GENE_LIST'] = human_gene_id['GENE_LIST'].str.replace('^,|', '')
human_gene_id['GENE_LIST'] = human_gene_id['GENE_LIST'].str.split('|')
human_gene_id = human_gene_id.explode('GENE_LIST')


mentha = pd.read_csv(PHENOLYZER_LIB / 'DB_MENTHA_GENE_GENE_INTERACTION', sep='\t', dtype=str)

omim_gene_dx = pd.read_csv(PHENOLYZER_LIB / 'DB_OMIM_GENE_DISEASE', sep='\t', dtype=str)
omim_gene_dx['GENE'] = omim_gene_dx['GENE'].str.replace(',$', '')
omim_gene_dx['GENE'] = omim_gene_dx['GENE'].str.replace('^,', '')
omim_gene_dx['GENE'] = omim_gene_dx['GENE'].str.split('\s*,\s*')
omim_gene_dx = omim_gene_dx.explode('GENE')


orphanet = pd.read_csv(PHENOLYZER_LIB / 'DB_ORPHANET_GENE_DISEASE', sep='\t', dtype=str,encoding= 'unicode_escape')
gwas = pd.read_csv(PHENOLYZER_LIB / 'DB_GWAS_GENE_DISEASE', sep='\t', dtype=str, encoding= 'unicode_escape')
clinvar = pd.read_csv(PHENOLYZER_LIB / 'DB_CLINVAR_GENE_DISEASE', sep='\t',  encoding= 'unicode_escape')


#Nothing to do for the following
#ctd = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_CTD_DISEASES', sep='\t', dtype=str)
#ctd_used = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_CTD_DISEASES_USED', sep='\t', dtype=str)
#dx_count = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_DISEASE_COUNT', sep='\t', dtype=str)
#omim_dx = pd.read_csv(PHENOLYZER_LIB / 'DB_COMPILED_OMIM_ID_DISEASE', sep='\t', dtype=str)
#omim_desc = pd.read_csv(PHENOLYZER_LIB / 'DB_OMIM_DESCRIPTION', sep='\t', dtype=str)

# %%
# HPO Frequencies from claims database
hpo_infant = pd.read_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Infants.tsv", delimiter = "\t")
hpo_child = pd.read_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Children.tsv", delimiter = "\t")
hpo_adolescent = pd.read_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Adolescent.tsv", delimiter = "\t")
hpo_adult = pd.read_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Adult.tsv", delimiter = "\t")
hpo_elderly = pd.read_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Elderly.tsv", delimiter = "\t")

# %%
hpo_2019 = obonet.read_obo(config.HPO_FILE)

# %% [markdown]
# # Map Phenotypes to 2019 HPO

# %%
preprocessor = preprocess.Preprocessor()
# Out:
# INFO:root:Initializing Gene Mappings....
# INFO:root:Reading hgnc mappings....
# INFO:root:Reading biomart mappings....
# INFO:root:Reading shilpa mappings....
# INFO:root:Reading ncbi mappings....
# INFO:root:Retrieving unique lists of genes....

# %%
hpoa_phen_diseases_2015 = preprocessor.map_phenotypes(hpoa_phen_diseases_2015)
hpoa_phen_genes_2015 = preprocessor.map_phenotypes(hpoa_phen_genes_2015)

# %% [markdown]
# # Map Genes to Ensembl ID

# %% [markdown]
# ## 2015 KG

# %%
human_gene_id = preprocessor.map_genes(human_gene_id, ['GENE_ID', 'GENE_LIST'])
print(len(human_gene_id))

human_gene_id_format = human_gene_id.sort_values('GENE_LIST').filter(['', 'GENE_ID_ensembl', 'GENE_LIST_ensembl'])\
    .groupby(['', 'GENE_ID_ensembl'], sort=False)['GENE_LIST_ensembl'].apply(list).reset_index()
human_gene_id_format['GENE_LIST_ensembl'] = human_gene_id_format['GENE_LIST_ensembl'].apply(lambda x: list(set([str(i) for i in x]))) #doing this to include null in list
human_gene_id_format['GENE_LIST_ensembl'] = human_gene_id_format['GENE_LIST_ensembl'].str.join('|')
human_gene_id_format.head()
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDAN4
# ERROR:root:The following gene can not be converted to an Ensembl ID: Zdhhc21
# ERROR:root:The following gene can not be converted to an Ensembl ID: Cyb5r1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ermn
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ439F8.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL22Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSMODG00000023111
# ERROR:root:The following gene can not be converted to an Ensembl ID: bK963H5.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10Q26
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: HYPLIP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd9
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb8
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6PTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: MOCODA
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2al2a
# ERROR:root:The following gene can not be converted to an Ensembl ID: l(3)02640
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q43Q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2az2
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: MVCD3
# ERROR:root:The following gene can not be converted to an Ensembl ID: hsRPB2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CADP44
# ERROR:root:The following gene can not be converted to an Ensembl ID: DR-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP7Q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q23.1Q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: tws
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT25
# ERROR:root:The following gene can not be converted to an Ensembl ID: mTERF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Pe1Fe10
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ788L20.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGpMiX
# ERROR:root:The following gene can not be converted to an Ensembl ID: C16DELQ22
# ERROR:root:The following gene can not be converted to an Ensembl ID: DNM1DN11-7
# ERROR:root:The following gene can not be converted to an Ensembl ID: WT4
# ERROR:root:The following gene can not be converted to an Ensembl ID: WAGRO
# ERROR:root:The following gene can not be converted to an Ensembl ID: EOE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1P32P31
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA556L1.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q23.1Q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXQ27.3Q28
# ERROR:root:The following gene can not be converted to an Ensembl ID: AIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DNAPTP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CL23945
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP22.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ977L11.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT35
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: BING5
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCLDS
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCR6
# ERROR:root:The following gene can not be converted to an Ensembl ID: CRH-R1h
# ERROR:root:The following gene can not be converted to an Ensembl ID: LUC7-LIKE
# ERROR:root:The following gene can not be converted to an Ensembl ID: dA59H18.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA261N11.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: EEN-2B-L3
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ691N24.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: UCK1-LIKE
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q21.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DKFZP564O0523
# ERROR:root:The following gene can not be converted to an Ensembl ID: HANAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: H_NH0187G20.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MPMGp800C04260Q003
# ERROR:root:The following gene can not be converted to an Ensembl ID: ISCW
# ERROR:root:The following gene can not be converted to an Ensembl ID: Gnas
# ERROR:root:The following gene can not be converted to an Ensembl ID: BBIS
# ERROR:root:The following gene can not be converted to an Ensembl ID: FIQTL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCR8
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPRS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DBA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASL13
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATOD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: MTBSX
# ERROR:root:The following gene can not be converted to an Ensembl ID: IPOX
# ERROR:root:The following gene can not be converted to an Ensembl ID: RLS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: LL0XNC01-157D4.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd9
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPSA
# ERROR:root:The following gene can not be converted to an Ensembl ID: ADIPQTL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q21.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ7
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ874C20.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: GRDX
# ERROR:root:The following gene can not be converted to an Ensembl ID: 70kD
# ERROR:root:The following gene can not be converted to an Ensembl ID: tbrd-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: NRCLP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: NOGOC
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG37
# ERROR:root:The following gene can not be converted to an Ensembl ID: Rtn4
# ERROR:root:The following gene can not be converted to an Ensembl ID: UAQTL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P21
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ520B18.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSNGAG00000017432
# ERROR:root:The following gene can not be converted to an Ensembl ID: Krtap3-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP18PDEL18Q
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: KAZA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGR2
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q41Q42
# ERROR:root:The following gene can not be converted to an Ensembl ID: OGS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: Celf4
# ERROR:root:The following gene can not be converted to an Ensembl ID: hBD-3
# ERROR:root:The following gene can not be converted to an Ensembl ID: POREN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL9P
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD7
# ERROR:root:The following gene can not be converted to an Ensembl ID: HALP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PTOS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: hLAT1
# ERROR:root:The following gene can not be converted to an Ensembl ID: H-IDHB
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK5
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRIP4Q32.1Q32.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: hMINK
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA189K21.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: l(3)02640
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRTS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: eloC
# ERROR:root:The following gene can not be converted to an Ensembl ID: MAGI2IT1
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ450M14.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: COOKL
# ERROR:root:The following gene can not be converted to an Ensembl ID: Vha44
# ERROR:root:The following gene can not be converted to an Ensembl ID: DNAPTP5
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRV222
# ERROR:root:The following gene can not be converted to an Ensembl ID: GPB.NY
# ERROR:root:The following gene can not be converted to an Ensembl ID: WUGSC:H_NH0187G20.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB2
# ERROR:root:The following gene can not be converted to an Ensembl ID: hnRNP R
# ERROR:root:The following gene can not be converted to an Ensembl ID: l(3)02640
# ERROR:root:The following gene can not be converted to an Ensembl ID: hNAT5
# ERROR:root:The following gene can not be converted to an Ensembl ID: hDcp1b
# ERROR:root:The following gene can not be converted to an Ensembl ID: Zkscan1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HsMar1
# ERROR:root:The following gene can not be converted to an Ensembl ID: mTERF3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT30
# ERROR:root:The following gene can not be converted to an Ensembl ID: mir-79
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMS1A1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPENCDI
# ERROR:root:The following gene can not be converted to an Ensembl ID: CLLS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Lyzl4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3Q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2Q32Q33
# ERROR:root:The following gene can not be converted to an Ensembl ID: DKFZP686I15217
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUH1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP21
# ERROR:root:The following gene can not be converted to an Ensembl ID: hPTPN20
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ulk1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: Kcng3
# ERROR:root:The following gene can not be converted to an Ensembl ID: AURORA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRXHF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: hNtr1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYQ11
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBFQTL4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT25
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: sens
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYQ11
# ERROR:root:The following gene can not be converted to an Ensembl ID: NMLFS
# ERROR:root:The following gene can not be converted to an Ensembl ID: bK250D10.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HC21orf7
# ERROR:root:The following gene can not be converted to an Ensembl ID: Zfp639
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2ax
# ERROR:root:The following gene can not be converted to an Ensembl ID: OPHLC
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXQ28
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6Q24Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: eIF4E1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTGH
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXQ28
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17P13.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDLCQ14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11P13
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVD12
# ERROR:root:The following gene can not be converted to an Ensembl ID: 100506863
# ERROR:root:The following gene can not be converted to an Ensembl ID: nPTB5
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHCM
# ERROR:root:The following gene can not be converted to an Ensembl ID: hMMTAG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q21.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: PAPA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: h-DRK1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NOGO-A
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA55K22.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRO9898
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2Q23.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: lama3a
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q43Q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: Vha44
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMTDIA
# ERROR:root:The following gene can not be converted to an Ensembl ID: hHb6
# ERROR:root:The following gene can not be converted to an Ensembl ID: OA3_H
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-45
# ERROR:root:The following gene can not be converted to an Ensembl ID: IPOX
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL13Q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: LGV2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVD10
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11P15P14
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT28
# ERROR:root:The following gene can not be converted to an Ensembl ID: nPTB6
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG50
# ERROR:root:The following gene can not be converted to an Ensembl ID: PIPKIg_v4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYQ11
# ERROR:root:The following gene can not be converted to an Ensembl ID: hMINKbeta
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CPFP
# ERROR:root:The following gene can not be converted to an Ensembl ID: C1orf18
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLRL
# ERROR:root:The following gene can not be converted to an Ensembl ID: AMMEC
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ366L4.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: 50-DAG
# ERROR:root:The following gene can not be converted to an Ensembl ID: GpMiIII
# ERROR:root:The following gene can not be converted to an Ensembl ID: ETL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: col4a1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Arsg
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP11.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: mTERF2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCT1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Kcnv2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCR7
# ERROR:root:The following gene can not be converted to an Ensembl ID: IGKJ
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ271M21.1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: hSAN
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYMY5
# ERROR:root:The following gene can not be converted to an Ensembl ID: AAT6
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTC-454M9.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: trnM(cau)
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd8
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ450M14.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ821D11.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: Tgm2
# ERROR:root:The following gene can not be converted to an Ensembl ID: G-ALPHA-h
# ERROR:root:The following gene can not be converted to an Ensembl ID: l(3)02640
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10Q26
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVC10
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHFL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDLCQ14
# ERROR:root:The following gene can not be converted to an Ensembl ID: KVEBN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: Lmx1b
# ERROR:root:The following gene can not be converted to an Ensembl ID: PROX1UP
# ERROR:root:The following gene can not be converted to an Ensembl ID: Sidt1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PTCH11
# ERROR:root:The following gene can not be converted to an Ensembl ID: Kcng4
# ERROR:root:The following gene can not be converted to an Ensembl ID: nPTB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: OPSIN-LCR
# ERROR:root:The following gene can not be converted to an Ensembl ID: FGQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: bK126B4.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ279A18.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: IMAGE3455200
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PHP1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: Uchl1
# ERROR:root:The following gene can not be converted to an Ensembl ID: D1S111
# ERROR:root:The following gene can not be converted to an Ensembl ID: CT-RCC-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPE7
# ERROR:root:The following gene can not be converted to an Ensembl ID: MAPK 4
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: Prex2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGpMiIII
# ERROR:root:The following gene can not be converted to an Ensembl ID: LP8067
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ708F5.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: ECT
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ682J15.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: GYPHe.NY
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRMD9
# ERROR:root:The following gene can not be converted to an Ensembl ID: UNC-43
# ERROR:root:The following gene can not be converted to an Ensembl ID: AOMS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P1.11659_5
# ERROR:root:The following gene can not be converted to an Ensembl ID: AMMEC
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGpMiVI
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEOA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: UGT1-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HMNJ
# ERROR:root:The following gene can not be converted to an Ensembl ID: Pe1Fe3
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLSM7
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3PTERP25
# ERROR:root:The following gene can not be converted to an Ensembl ID: hCMT1c
# ERROR:root:The following gene can not be converted to an Ensembl ID: CELIAC5
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2az1
# ERROR:root:The following gene can not be converted to an Ensembl ID: 1B4
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYMY4
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSBTAG00000030468
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLH2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Mir29b-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIEE7
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUH3
# ERROR:root:The following gene can not be converted to an Ensembl ID: hsa-mir-1273a
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd4
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: db-s
# ERROR:root:The following gene can not be converted to an Ensembl ID: Spaca3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6Q11Q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMD1BB
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb7
# ERROR:root:The following gene can not be converted to an Ensembl ID: NMLFS
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEE4
# ERROR:root:The following gene can not be converted to an Ensembl ID: EA2.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXP11.23P11.22
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATOD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: CP20
# ERROR:root:The following gene can not be converted to an Ensembl ID: PROMETHIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME4
# ERROR:root:The following gene can not be converted to an Ensembl ID: PAND1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P12.1P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CRHR1f
# ERROR:root:The following gene can not be converted to an Ensembl ID: BCLXL
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLSM7
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ16
# ERROR:root:The following gene can not be converted to an Ensembl ID: Lcn9
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSMUSG00000031781
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd3
# ERROR:root:The following gene can not be converted to an Ensembl ID: FBgn0021874
# ERROR:root:The following gene can not be converted to an Ensembl ID: IPLA2(GAMMA)
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: hsa-mir-1254-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBFQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP22Q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P16.1-P15
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-220
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BCLXS
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBFQTL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA552M11.5
# ERROR:root:The following gene can not be converted to an Ensembl ID: TEMTYS
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGC:1902
# ERROR:root:The following gene can not be converted to an Ensembl ID: DNM1DN4-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCLC1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: FBgn0039066
# ERROR:root:The following gene can not be converted to an Ensembl ID: FMO 1B1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MONaKA
# ERROR:root:The following gene can not be converted to an Ensembl ID: KV9.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: TET1-MLL
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP2Q31.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: IGAN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Angpt4
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ8
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q43Q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMS1A1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GNAH
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q26QTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ271M21.1.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Polr2k
# ERROR:root:The following gene can not be converted to an Ensembl ID: EL-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: RFH1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NF-kappa-B
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDLCQ2
# ERROR:root:The following gene can not be converted to an Ensembl ID: POF8
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxd12
# ERROR:root:The following gene can not be converted to an Ensembl ID: H1f5
# ERROR:root:The following gene can not be converted to an Ensembl ID: Rtn4
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ1104E15.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ468O1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: hDKIR
# ERROR:root:The following gene can not be converted to an Ensembl ID: CUP2Q35
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-70
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG53
# ERROR:root:The following gene can not be converted to an Ensembl ID: CUP2Q35
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHT3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL5Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: ALS14
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCUb
# ERROR:root:The following gene can not be converted to an Ensembl ID: Pe1Fe6
# ERROR:root:The following gene can not be converted to an Ensembl ID: PDE4B5
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP3Q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: IGLJ
# ERROR:root:The following gene can not be converted to an Ensembl ID: RP68
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL22Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: GDCG4p14.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBMPFD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOP4
# ERROR:root:The following gene can not be converted to an Ensembl ID: LCA17
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL113
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1P36
# ERROR:root:The following gene can not be converted to an Ensembl ID: FerT
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hoxb6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL18P
# ERROR:root:The following gene can not be converted to an Ensembl ID: Krtap3-3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: hGWL
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK4
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGR4
# ERROR:root:The following gene can not be converted to an Ensembl ID: linc-MD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXQ21
# ERROR:root:The following gene can not be converted to an Ensembl ID: LEPQTL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPCDRG
# ERROR:root:The following gene can not be converted to an Ensembl ID: EWS-WT1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT36
# ERROR:root:The following gene can not be converted to an Ensembl ID: CANDF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q15.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSULF-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: nPTB8
# ERROR:root:The following gene can not be converted to an Ensembl ID: Vha44
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA100C15.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Mast1
# ERROR:root:The following gene can not be converted to an Ensembl ID: AK 2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CHNG3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP5P13
# ERROR:root:The following gene can not be converted to an Ensembl ID: KTWS
# ERROR:root:The following gene can not be converted to an Ensembl ID: Em:AC068896.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL7Q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: dJ74J1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ18
# ERROR:root:The following gene can not be converted to an Ensembl ID: AFA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSNGAG00000011615
# ERROR:root:The following gene can not be converted to an Ensembl ID: Krtap2-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CELIAC6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA535F17.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Pe1Fe13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q12Q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPDA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGR1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRO21339
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCLC1
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK6
# ERROR:root:The following gene can not be converted to an Ensembl ID: EA1.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: FMTLE
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: OTDD
# ERROR:root:The following gene can not be converted to an Ensembl ID: 15LOX-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT37
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA110J1.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: bK268H5.5
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDLCQ14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DRw10
# ERROR:root:The following gene can not be converted to an Ensembl ID: PDON2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q24
# ERROR:root:The following gene can not be converted to an Ensembl ID: bA146B14.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Thop1
# ERROR:root:The following gene can not be converted to an Ensembl ID: VAMAS6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL4Q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: hGKAP
# ERROR:root:The following gene can not be converted to an Ensembl ID: KV2.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BRWS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: IH
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL14Q11Q22
# ERROR:root:The following gene can not be converted to an Ensembl ID: HH12
# ERROR:root:The following gene can not be converted to an Ensembl ID: Frmd3
# ERROR:root:The following gene can not be converted to an Ensembl ID: D1S111
# ERROR:root:The following gene can not be converted to an Ensembl ID: ADIPQTL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: MR1P1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Spg20
# ERROR:root:The following gene can not be converted to an Ensembl ID: TNFR1-d2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: Krtap3-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: minichain
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRIM59-IFT80
# ERROR:root:The following gene can not be converted to an Ensembl ID: hPLB
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19Q13.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: OTDD
# ERROR:root:The following gene can not be converted to an Ensembl ID: PLSA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Dnase1l1
# ERROR:root:The following gene can not be converted to an Ensembl ID: OCTN2VT
# ERROR:root:The following gene can not be converted to an Ensembl ID: C6orf34B
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLL/GAS7
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYO1GUN
# ERROR:root:The following gene can not be converted to an Ensembl ID: FGQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: TIIAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ugt1a9
# ERROR:root:The following gene can not be converted to an Ensembl ID: Par3Lb
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3Q13.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: UVM2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-73
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG54
# ERROR:root:The following gene can not be converted to an Ensembl ID: PAR3LC
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFNS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: RPL36AP52
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: OPHLC
# ERROR:root:The following gene can not be converted to an Ensembl ID: hRasGRP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: hASNA-I
# ERROR:root:The following gene can not be converted to an Ensembl ID: Krtap4-7
# ERROR:root:The following gene can not be converted to an Ensembl ID: FKSG49
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSBTAG00000002046
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P12P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP1Q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: BZX
# 83224
#      GENE_ID GENE_LIST GENE_LIST_ensembl GENE_LIST_mapping_status
# 0  1    A1BG       A1B   ENSG00000172164        mapped to ensembl
# 0  1    A1BG       ABG   ENSG00000121410        mapped to ensembl
# 0  1    A1BG       GAB   ENSG00000121410        mapped to ensembl
# 0  1    A1BG  HYST2477   ENSG00000121410        mapped to ensembl
# 1  2     A2M      A2MD   ENSG00000175899        mapped to ensembl

# %%
gene_dx = preprocessor.map_genes(gene_dx, ['GENE'])
gene_dx.head()
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDAN4
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T14
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE36
# ERROR:root:The following gene can not be converted to an Ensembl ID: EVI3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BETA-GLOBIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: DGKDELTA
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAHbeta
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16Q22
# ERROR:root:The following gene can not be converted to an Ensembl ID: SF3B150
# ERROR:root:The following gene can not be converted to an Ensembl ID: CALMBP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCMPMLTNA
# ERROR:root:The following gene can not be converted to an Ensembl ID: PKC-BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSERT
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA338L11.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA393I2.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW199
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHB6
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBR-STL-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: H1S-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDGKZETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYHC-IIA
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T10
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCLC-KA
# ERROR:root:The following gene can not be converted to an Ensembl ID: Slc4a4
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYHAS8
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1018A4.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-18RACP
# ERROR:root:The following gene can not be converted to an Ensembl ID: UBCM2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HOX-4.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10Q26
# ERROR:root:The following gene can not be converted to an Ensembl ID: P33(CDK2)
# ERROR:root:The following gene can not be converted to an Ensembl ID: NATOB
# ERROR:root:The following gene can not be converted to an Ensembl ID: HYPLIP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HK1-TA
# ERROR:root:The following gene can not be converted to an Ensembl ID: FSTNI
# ERROR:root:The following gene can not be converted to an Ensembl ID: HOR5'BETA5
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE81
# ERROR:root:The following gene can not be converted to an Ensembl ID: OLFC
# ERROR:root:The following gene can not be converted to an Ensembl ID: MAP1LC3B-A
# ERROR:root:The following gene can not be converted to an Ensembl ID: KCA4.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HP51CN
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST771
# ERROR:root:The following gene can not be converted to an Ensembl ID: SSECKS
# ERROR:root:The following gene can not be converted to an Ensembl ID: HFAF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ303F19.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NAV1.5
# ERROR:root:The following gene can not be converted to an Ensembl ID: SQC
# ERROR:root:The following gene can not be converted to an Ensembl ID: MITAAT
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ579F20.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DRI42
# ERROR:root:The following gene can not be converted to an Ensembl ID: GPRV17
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHLP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: 3H11AG
# ERROR:root:The following gene can not be converted to an Ensembl ID: FCGR
# ERROR:root:The following gene can not be converted to an Ensembl ID: TEN-M3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HG28K
# ERROR:root:The following gene can not be converted to an Ensembl ID: CKLIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: MINICHAIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: NA(V)1.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: NFKB-P105
# ERROR:root:The following gene can not be converted to an Ensembl ID: znf462
# ERROR:root:The following gene can not be converted to an Ensembl ID: P180-ERBB3
# ERROR:root:The following gene can not be converted to an Ensembl ID: SNGPX
# ERROR:root:The following gene can not be converted to an Ensembl ID: 647020
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGWL
# ERROR:root:The following gene can not be converted to an Ensembl ID: MOCODA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA455B2.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CGKI-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: RSC786
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRDGBBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: IMPNB
# ERROR:root:The following gene can not be converted to an Ensembl ID: FINGER7
# ERROR:root:The following gene can not be converted to an Ensembl ID: SIGMA1R
# ERROR:root:The following gene can not be converted to an Ensembl ID: MT-1L
# ERROR:root:The following gene can not be converted to an Ensembl ID: GRIP104
# ERROR:root:The following gene can not be converted to an Ensembl ID: SIX9
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST19550
# ERROR:root:The following gene can not be converted to an Ensembl ID: ILDR1ALPHA'
# ERROR:root:The following gene can not be converted to an Ensembl ID: M-RDGB-BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRP4P
# ERROR:root:The following gene can not be converted to an Ensembl ID: M-SEMAK
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBUB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q43Q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: EN
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-94N
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: IFN-ALPHAD
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST18676
# ERROR:root:The following gene can not be converted to an Ensembl ID: 2700063A19RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: C10DUPQ24
# ERROR:root:The following gene can not be converted to an Ensembl ID: MVCD3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAM-PDE 1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: LTG
# ERROR:root:The following gene can not be converted to an Ensembl ID: DIPP3B
# ERROR:root:The following gene can not be converted to an Ensembl ID: RD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: RETSDR4
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRS2ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ71N10.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ266L20.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDIS3L2
# ERROR:root:The following gene can not be converted to an Ensembl ID: C15DELQ26QTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHA29
# ERROR:root:The following gene can not be converted to an Ensembl ID: YDL201W
# ERROR:root:The following gene can not be converted to an Ensembl ID: COOL-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CADP44
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-7R-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: C-LBC
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ353E16.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ALPHA-PIX
# ERROR:root:The following gene can not be converted to an Ensembl ID: P140-TRKA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBRF
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDMP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLP5
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE12
# ERROR:root:The following gene can not be converted to an Ensembl ID: NM15
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIF3-P46
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA59I9.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: C11DELP15P14
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHB27
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZNF635M
# ERROR:root:The following gene can not be converted to an Ensembl ID: EU-HMTASE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MTTFB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHA45
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT25
# ERROR:root:The following gene can not be converted to an Ensembl ID: 2610017G09RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHB20
# ERROR:root:The following gene can not be converted to an Ensembl ID: UMAT
# ERROR:root:The following gene can not be converted to an Ensembl ID: SNOI
# ERROR:root:The following gene can not be converted to an Ensembl ID: K(VCA)BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGLU4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ382I10.6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ468O1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SMGGDS
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA528A10.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: B3GLC-T
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST18717
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ctnnd1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP2C-ETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2B/R
# ERROR:root:The following gene can not be converted to an Ensembl ID: GPX-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: SM-D2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MATH4B
# ERROR:root:The following gene can not be converted to an Ensembl ID: MIG20A
# ERROR:root:The following gene can not be converted to an Ensembl ID: TAIFA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HKNL-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GSD1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: SF3B49
# ERROR:root:The following gene can not be converted to an Ensembl ID: LNCRNA-ES3
# ERROR:root:The following gene can not be converted to an Ensembl ID: WT4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CXQ28
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA386N14.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA18I14.5
# ERROR:root:The following gene can not be converted to an Ensembl ID: 6330578E17RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: EOE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: B(P51B)
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTFGAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW293
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUDLIN-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: SK521
# ERROR:root:The following gene can not be converted to an Ensembl ID: BRPTB
# ERROR:root:The following gene can not be converted to an Ensembl ID: CKB10
# ERROR:root:The following gene can not be converted to an Ensembl ID: CXDELQ21
# ERROR:root:The following gene can not be converted to an Ensembl ID: NASI-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SRRP40
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ697K14.9
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL1R-RP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-63P
# ERROR:root:The following gene can not be converted to an Ensembl ID: BQB115I13.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: P53LYN
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPTPZETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: M-RAS
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE77
# ERROR:root:The following gene can not be converted to an Ensembl ID: MIMITIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: 5QNCA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BETA3GAL-T5
# ERROR:root:The following gene can not be converted to an Ensembl ID: CC1QR
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P3.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRO-NRG3
# ERROR:root:The following gene can not be converted to an Ensembl ID: AIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: GPCR26
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ75N13.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA421M1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLT4-L
# ERROR:root:The following gene can not be converted to an Ensembl ID: T-SYNTHASE
# ERROR:root:The following gene can not be converted to an Ensembl ID: P110D
# ERROR:root:The following gene can not be converted to an Ensembl ID: ES2EL
# ERROR:root:The following gene can not be converted to an Ensembl ID: C6DELPTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ794I6.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: C16DUPQ36.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-22R-ALPHA-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CHSY-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLUN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CISH5
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW125
# ERROR:root:The following gene can not be converted to an Ensembl ID: C-E10
# ERROR:root:The following gene can not be converted to an Ensembl ID: P40.5
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRPB140
# ERROR:root:The following gene can not be converted to an Ensembl ID: O-FUCT-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: WALP3
# ERROR:root:The following gene can not be converted to an Ensembl ID: P24ING1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: GHHKB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-647
# ERROR:root:The following gene can not be converted to an Ensembl ID: CL23945
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRPE65
# ERROR:root:The following gene can not be converted to an Ensembl ID: P39NCK5AI
# ERROR:root:The following gene can not be converted to an Ensembl ID: ABCB5BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA160E12.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: P59-FYN
# ERROR:root:The following gene can not be converted to an Ensembl ID: 6CKINE
# ERROR:root:The following gene can not be converted to an Ensembl ID: P33ING1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ22I17.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: METAP 1D
# ERROR:root:The following gene can not be converted to an Ensembl ID: CBLD
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHR21
# ERROR:root:The following gene can not be converted to an Ensembl ID: VPS32-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: SETAGIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRFT2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCPEB-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NCKBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHB11
# ERROR:root:The following gene can not be converted to an Ensembl ID: P90-RSK2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT35
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRPRS
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATM1P
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-1R-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: PJA923
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCDC18
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLAMINGO1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PIP5KIIBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPEGALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: EBFAZ
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGCMB
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL7Q
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ149M18.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SM-N
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZNF20-LP
# ERROR:root:The following gene can not be converted to an Ensembl ID: N-MYC
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP125FAK
# ERROR:root:The following gene can not be converted to an Ensembl ID: ACECS2L
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA541N10.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLO-BETA-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hdac9
# ERROR:root:The following gene can not be converted to an Ensembl ID: SRP1GAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPTIIA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DYT5A
# ERROR:root:The following gene can not be converted to an Ensembl ID: CIPP
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA355M14.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PE1FE3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HM74B
# ERROR:root:The following gene can not be converted to an Ensembl ID: N-OCT3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PROSAPIP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD42A
# ERROR:root:The following gene can not be converted to an Ensembl ID: BCR/ABL
# ERROR:root:The following gene can not be converted to an Ensembl ID: SU48
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCLDS
# ERROR:root:The following gene can not be converted to an Ensembl ID: 1110001C14RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: SEC8P
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD4MUT
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYR4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HC-GP39
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ37E16.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: BETA3GN-T4
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ45831
# ERROR:root:The following gene can not be converted to an Ensembl ID: HKFC-B
# ERROR:root:The following gene can not be converted to an Ensembl ID: GNT I.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: RABEX-5
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATLASTIN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HREV
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPRP18
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCR6
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPRP6
# ERROR:root:The following gene can not be converted to an Ensembl ID: UNC-93B1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GADD45GAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: NAKED1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MATH5
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA418P12.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FBHOK
# ERROR:root:The following gene can not be converted to an Ensembl ID: ERRB
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSK4
# ERROR:root:The following gene can not be converted to an Ensembl ID: H3-K9-HMTASE4
# ERROR:root:The following gene can not be converted to an Ensembl ID: RCNCBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA64J21.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NBLA02999
# ERROR:root:The following gene can not be converted to an Ensembl ID: P528
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA465L10.6
# ERROR:root:The following gene can not be converted to an Ensembl ID: U-PA
# ERROR:root:The following gene can not be converted to an Ensembl ID: PMCA2A
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRIP-BR2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTG3A
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD218B
# ERROR:root:The following gene can not be converted to an Ensembl ID: RCNCA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA430M15.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCD84
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDPS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: C14_5685
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSMAR1
# ERROR:root:The following gene can not be converted to an Ensembl ID: TGFBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: RAB11-FIP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: TYRO5
# ERROR:root:The following gene can not be converted to an Ensembl ID: GENESIS
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCAM3
# ERROR:root:The following gene can not be converted to an Ensembl ID: LUC7-LIKE
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-622
# ERROR:root:The following gene can not be converted to an Ensembl ID: GA55
# ERROR:root:The following gene can not be converted to an Ensembl ID: ER-CHL
# ERROR:root:The following gene can not be converted to an Ensembl ID: P53CP
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBEAGBP4A
# ERROR:root:The following gene can not be converted to an Ensembl ID: ERP90
# ERROR:root:The following gene can not be converted to an Ensembl ID: MDC-LM
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTDAG8
# ERROR:root:The following gene can not be converted to an Ensembl ID: HKVB3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HS6M1-6
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPTB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: EEN-2B-L3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHD13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ248E1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SE20-9
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRGS17
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ512B11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSPE-39
# ERROR:root:The following gene can not be converted to an Ensembl ID: DRW10
# ERROR:root:The following gene can not be converted to an Ensembl ID: NCL-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HIF-1-BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAMKN
# ERROR:root:The following gene can not be converted to an Ensembl ID: UCK1-LIKE
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLIT-3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCG_1745121
# ERROR:root:The following gene can not be converted to an Ensembl ID: GM-CSF-R-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HOLFD
# ERROR:root:The following gene can not be converted to an Ensembl ID: RSC6P
# ERROR:root:The following gene can not be converted to an Ensembl ID: Npas4
# ERROR:root:The following gene can not be converted to an Ensembl ID: TPL-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: STSLC-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SE2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLHX2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ477O4.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: GCOM
# ERROR:root:The following gene can not be converted to an Ensembl ID: HANAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-640
# ERROR:root:The following gene can not be converted to an Ensembl ID: YT14R
# ERROR:root:The following gene can not be converted to an Ensembl ID: DFY
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLCUAT-I
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEK6
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRK-B
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE14
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCD84
# ERROR:root:The following gene can not be converted to an Ensembl ID: ST8SIAI
# ERROR:root:The following gene can not be converted to an Ensembl ID: ITS
# ERROR:root:The following gene can not be converted to an Ensembl ID: lin28a
# ERROR:root:The following gene can not be converted to an Ensembl ID: FIL1-THETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: CK-2E
# ERROR:root:The following gene can not be converted to an Ensembl ID: SMC1ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: ULIP6
# ERROR:root:The following gene can not be converted to an Ensembl ID: HET-AR
# ERROR:root:The following gene can not be converted to an Ensembl ID: H_NH0187G20.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P493F12
# ERROR:root:The following gene can not be converted to an Ensembl ID: P94
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSN3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZFP523
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ353C17.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: P120GAP
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA351K16
# ERROR:root:The following gene can not be converted to an Ensembl ID: OCT-1B
# ERROR:root:The following gene can not be converted to an Ensembl ID: ACRG
# ERROR:root:The following gene can not be converted to an Ensembl ID: SEJ
# ERROR:root:The following gene can not be converted to an Ensembl ID: NAV2.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ496H19.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CA(V)T.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HUADC
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ292B18.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRAGILIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: 17B-HSD10
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA204B7.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA164L23.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ44796
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLCB2A
# ERROR:root:The following gene can not be converted to an Ensembl ID: IB772
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLUK1
# ERROR:root:The following gene can not be converted to an Ensembl ID: 3110013H01RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: P15INK4B
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZCYTOR5
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAMKID
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA307F22.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CLIC2B
# ERROR:root:The following gene can not be converted to an Ensembl ID: baz
# ERROR:root:The following gene can not be converted to an Ensembl ID: Gnas
# ERROR:root:The following gene can not be converted to an Ensembl ID: BBIS
# ERROR:root:The following gene can not be converted to an Ensembl ID: FIQTL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GT-V
# ERROR:root:The following gene can not be converted to an Ensembl ID: PMCA4X
# ERROR:root:The following gene can not be converted to an Ensembl ID: GB4CER
# ERROR:root:The following gene can not be converted to an Ensembl ID: YNG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ERDJ4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HIRK
# ERROR:root:The following gene can not be converted to an Ensembl ID: HAG-3
# ERROR:root:The following gene can not be converted to an Ensembl ID: Birc3
# ERROR:root:The following gene can not be converted to an Ensembl ID: Apoa2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ223E3.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHRML
# ERROR:root:The following gene can not be converted to an Ensembl ID: MAR4
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCD48
# ERROR:root:The following gene can not be converted to an Ensembl ID: NECTIN-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FBX31
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ44385
# ERROR:root:The following gene can not be converted to an Ensembl ID: nan
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ351K20.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP9Q21.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA196N14.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2A/Y
# ERROR:root:The following gene can not be converted to an Ensembl ID: UNPH
# ERROR:root:The following gene can not be converted to an Ensembl ID: C1QR(P)
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA514O12.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCR8
# ERROR:root:The following gene can not be converted to an Ensembl ID: GB3S
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPRS
# ERROR:root:The following gene can not be converted to an Ensembl ID: PKONX1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: DBA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ366L4.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASL13
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATOD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: OKSWCL45
# ERROR:root:The following gene can not be converted to an Ensembl ID: MTBSX
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDIA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-656
# ERROR:root:The following gene can not be converted to an Ensembl ID: RLS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GP250
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA153I24.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PNR-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA325O24.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PMCA2I
# ERROR:root:The following gene can not be converted to an Ensembl ID: IKK-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: GSG3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PLCETA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSPCA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P19-INK4D
# ERROR:root:The following gene can not be converted to an Ensembl ID: RAF-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HELD
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-123M
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMAL1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCHNURRI-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPSA
# ERROR:root:The following gene can not be converted to an Ensembl ID: ADIPQTL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: SFDALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: FORMACTIN2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: PDP1679
# ERROR:root:The following gene can not be converted to an Ensembl ID: HAVCR-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ELOX3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA133M9.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: LAMA3A
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCLP46
# ERROR:root:The following gene can not be converted to an Ensembl ID: MART4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CKIA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ7
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRANKL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST18872
# ERROR:root:The following gene can not be converted to an Ensembl ID: WDR10P
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAJALIN-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P13.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSMG5/7A
# ERROR:root:The following gene can not be converted to an Ensembl ID: PIPKIG_V4
# ERROR:root:The following gene can not be converted to an Ensembl ID: GRDX
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPKC-DELTA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTG737
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHA46
# ERROR:root:The following gene can not be converted to an Ensembl ID: TILZ4A
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSNF2B
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBD-28
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-70P
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBUBR1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GIE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Dner
# ERROR:root:The following gene can not be converted to an Ensembl ID: C1DUPP31.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPEBP4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGPMIV
# ERROR:root:The following gene can not be converted to an Ensembl ID: BKBETA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: QPS3
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T15
# ERROR:root:The following gene can not be converted to an Ensembl ID: TECH
# ERROR:root:The following gene can not be converted to an Ensembl ID: PKC-GAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ75H8.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE79
# ERROR:root:The following gene can not be converted to an Ensembl ID: NRCLP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD300F
# ERROR:root:The following gene can not be converted to an Ensembl ID: NOGOC
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLHB
# ERROR:root:The following gene can not be converted to an Ensembl ID: P42-MAPK
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA307O14.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEX26PM1T
# ERROR:root:The following gene can not be converted to an Ensembl ID: NAV1.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: UKVH5D
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P16.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSCP30
# ERROR:root:The following gene can not be converted to an Ensembl ID: PSMB5I
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCREM-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: LZT-HS7
# ERROR:root:The following gene can not be converted to an Ensembl ID: GNT-I.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: GPIA*
# ERROR:root:The following gene can not be converted to an Ensembl ID: P34-ARC
# ERROR:root:The following gene can not be converted to an Ensembl ID: CCT-EPSILON
# ERROR:root:The following gene can not be converted to an Ensembl ID: HFKHLA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1111A8.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FUCT-VI
# ERROR:root:The following gene can not be converted to an Ensembl ID: TIEG3
# ERROR:root:The following gene can not be converted to an Ensembl ID: LEM4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HK1-TC
# ERROR:root:The following gene can not be converted to an Ensembl ID: FERT
# ERROR:root:The following gene can not be converted to an Ensembl ID: RD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATP12P
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA129M16.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MITONEET
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPRLRI
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP1BP55
# ERROR:root:The following gene can not be converted to an Ensembl ID: ST3GALA.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MIRNA146B
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ501N12.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11Q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: THING1
# ERROR:root:The following gene can not be converted to an Ensembl ID: TCP-1-EPSILON
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHA13
# ERROR:root:The following gene can not be converted to an Ensembl ID: MTRP
# ERROR:root:The following gene can not be converted to an Ensembl ID: HMLH1
# ERROR:root:The following gene can not be converted to an Ensembl ID: G18.1B
# ERROR:root:The following gene can not be converted to an Ensembl ID: P85-SERBB3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZETA-COP
# ERROR:root:The following gene can not be converted to an Ensembl ID: PREF-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NESP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ca3
# ERROR:root:The following gene can not be converted to an Ensembl ID: 644727
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ718P11
# ERROR:root:The following gene can not be converted to an Ensembl ID: RHVIII
# ERROR:root:The following gene can not be converted to an Ensembl ID: HFAT1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTSP
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE76
# ERROR:root:The following gene can not be converted to an Ensembl ID: RHII
# ERROR:root:The following gene can not be converted to an Ensembl ID: CISH2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HVPLA(2)
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ393D12.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHCP-6
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTSHR-I
# ERROR:root:The following gene can not be converted to an Ensembl ID: PARP-5A
# ERROR:root:The following gene can not be converted to an Ensembl ID: GABABRBP
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2B/L
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAV3.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: PRRPR
# ERROR:root:The following gene can not be converted to an Ensembl ID: KAZA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BNAC1
# ERROR:root:The following gene can not be converted to an Ensembl ID: GROG
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA18I14.8
# ERROR:root:The following gene can not be converted to an Ensembl ID: AKAP-LBC
# ERROR:root:The following gene can not be converted to an Ensembl ID: MAXP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: TREM2B
# ERROR:root:The following gene can not be converted to an Ensembl ID: BGL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW136
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSNF2H
# ERROR:root:The following gene can not be converted to an Ensembl ID: HMAT-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSPK21
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGR2
# ERROR:root:The following gene can not be converted to an Ensembl ID: B-RAF
# ERROR:root:The following gene can not be converted to an Ensembl ID: JUNCTIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE20
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGLE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: IK3-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPADVI
# ERROR:root:The following gene can not be converted to an Ensembl ID: Hcar2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNAP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PKC-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST17287
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSPRY2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGSA-A
# ERROR:root:The following gene can not be converted to an Ensembl ID: OGS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEA2AA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ860F19.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST441
# ERROR:root:The following gene can not be converted to an Ensembl ID: BERG36
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA188C12.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: LNCRNA-N3
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPINK3
# ERROR:root:The following gene can not be converted to an Ensembl ID: AP-2ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: P59-OASL
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIF-4H
# ERROR:root:The following gene can not be converted to an Ensembl ID: Celf4
# ERROR:root:The following gene can not be converted to an Ensembl ID: RCNCALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: S30MT
# ERROR:root:The following gene can not be converted to an Ensembl ID: P110(NRB)
# ERROR:root:The following gene can not be converted to an Ensembl ID: HUNC18B
# ERROR:root:The following gene can not be converted to an Ensembl ID: H3-OST-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ583P15.8
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNR3
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA205K10.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ccl20
# ERROR:root:The following gene can not be converted to an Ensembl ID: TMDCIII
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ca4
# ERROR:root:The following gene can not be converted to an Ensembl ID: POREN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA360O19.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNF4ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCD40L
# ERROR:root:The following gene can not be converted to an Ensembl ID: 8430410J10RIK
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ing3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASC1P50
# ERROR:root:The following gene can not be converted to an Ensembl ID: NEU-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP2CKAPPA
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPKC-D2
# ERROR:root:The following gene can not be converted to an Ensembl ID: C5B
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRRP-40
# ERROR:root:The following gene can not be converted to an Ensembl ID: GSHPX-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: Sertad2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ494G10.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ760C5.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-LET-7G
# ERROR:root:The following gene can not be converted to an Ensembl ID: ZETA1-COP
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST17266
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-68P
# ERROR:root:The following gene can not be converted to an Ensembl ID: BETA4GAL-T5
# ...
# ERROR:root:The following gene can not be converted to an Ensembl ID: P621
# ERROR:root:The following gene can not be converted to an Ensembl ID: CBLG
# ERROR:root:The following gene can not be converted to an Ensembl ID: CkIIalpha-i1
# ERROR:root:The following gene can not be converted to an Ensembl ID: ALPHA1AT
# ERROR:root:The following gene can not be converted to an Ensembl ID: PADPRT-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: PLSA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: LBP/P40
# ERROR:root:The following gene can not be converted to an Ensembl ID: AMNIONLESS
# ERROR:root:The following gene can not be converted to an Ensembl ID: Htr1a
# ERROR:root:The following gene can not be converted to an Ensembl ID: HS6M1-27
# ERROR:root:The following gene can not be converted to an Ensembl ID: VZG-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGC-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CRH-R1H
# ERROR:root:The following gene can not be converted to an Ensembl ID: OCTN2VT
# ERROR:root:The following gene can not be converted to an Ensembl ID: Havcr2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PE1FE10
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLL/GAS7
# ERROR:root:The following gene can not be converted to an Ensembl ID: LOOPADR
# ERROR:root:The following gene can not be converted to an Ensembl ID: NBLA10993
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA432J24.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ482C21.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HKVBETA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: AF17Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q24
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P9.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HFPG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: B3GALT-V
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCHT
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-32BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE42
# ERROR:root:The following gene can not be converted to an Ensembl ID: RIM4GAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-100N
# ERROR:root:The following gene can not be converted to an Ensembl ID: S6K-ALPHA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ591C20.7
# ERROR:root:The following gene can not be converted to an Ensembl ID: PNO40
# ERROR:root:The following gene can not be converted to an Ensembl ID: DNCHC1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA371L19.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW325
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q24.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HT31
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA209J19.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUTPASE
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPAAT-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLGA
# ERROR:root:The following gene can not be converted to an Ensembl ID: SELADIN-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: H-SEMA-L
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARRESTEN
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCS-BETAA
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIF-2BBETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: FGQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: TIIAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPD-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P59OASL
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSAN
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ520B18.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ALPHA-MHC
# ERROR:root:The following gene can not be converted to an Ensembl ID: Ugt1a9
# ERROR:root:The following gene can not be converted to an Ensembl ID: PROSAP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FSAPB
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA472E5.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: C6DELQ25Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2B/G
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRASGRP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD235B
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP2C-EPSILON
# ERROR:root:The following gene can not be converted to an Ensembl ID: C3B-INA
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD107B
# ERROR:root:The following gene can not be converted to an Ensembl ID: APOA-II
# ERROR:root:The following gene can not be converted to an Ensembl ID: PREBP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SGIGSF
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLUA4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDG1A
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNF4A9
# ERROR:root:The following gene can not be converted to an Ensembl ID: HFIP1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P59 OASL
# ERROR:root:The following gene can not be converted to an Ensembl ID: GYPHE.NY
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRAD50
# ERROR:root:The following gene can not be converted to an Ensembl ID: GALNAC-T
# ERROR:root:The following gene can not be converted to an Ensembl ID: UVM2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1068F16.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-1G
# ERROR:root:The following gene can not be converted to an Ensembl ID: P55-R
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1187M17.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDEC2
# ERROR:root:The following gene can not be converted to an Ensembl ID: P116RIP
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ304B14.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLKB1
# ERROR:root:The following gene can not be converted to an Ensembl ID: RANBP11
# ERROR:root:The following gene can not be converted to an Ensembl ID: CI-24K
# ERROR:root:The following gene can not be converted to an Ensembl ID: CXINSQ27.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BP35
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL27P28
# ERROR:root:The following gene can not be converted to an Ensembl ID: RCOR-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRIT1-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: HOX-4.7
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ221C16.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA196N14.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ317G22.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MIG-14
# ERROR:root:The following gene can not be converted to an Ensembl ID: KV7.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIF3-GAMMA
# ERROR:root:The following gene can not be converted to an Ensembl ID: NECL-5
# ERROR:root:The following gene can not be converted to an Ensembl ID: Mpdu1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-1236
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA454H24.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ41423
# ERROR:root:The following gene can not be converted to an Ensembl ID: MIR-96
# ERROR:root:The following gene can not be converted to an Ensembl ID: ROBPI
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEL-S-73
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-181A-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE82
# ERROR:root:The following gene can not be converted to an Ensembl ID: HEST2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA526K24.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPIR-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BETA-NGF
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNRNP A1
# ERROR:root:The following gene can not be converted to an Ensembl ID: VES-1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHFDG1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSOD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD210A
# ERROR:root:The following gene can not be converted to an Ensembl ID: IL-1RACP
# ERROR:root:The following gene can not be converted to an Ensembl ID: PAR3LC
# ERROR:root:The following gene can not be converted to an Ensembl ID: CHAPSYN-110
# ERROR:root:The following gene can not be converted to an Ensembl ID: NOGO-C
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNEDD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: NOGO-B
# ERROR:root:The following gene can not be converted to an Ensembl ID: C14_5527
# ERROR:root:The following gene can not be converted to an Ensembl ID: RAFTLIN-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: TMP494178
# ERROR:root:The following gene can not be converted to an Ensembl ID: GSTM1B-1B
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFNS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA100C15.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HUCHA60
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP7Q36.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: OCT-T1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCLIM1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYOCILIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: P21CDC42HS
# ERROR:root:The following gene can not be converted to an Ensembl ID: CKB8
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLUK5
# ERROR:root:The following gene can not be converted to an Ensembl ID: C367G8.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: SRRP53
# ERROR:root:The following gene can not be converted to an Ensembl ID: RHIVB(J)
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ734G22.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ137F1.4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HGPMIX
# ERROR:root:The following gene can not be converted to an Ensembl ID: HVPS41P
# ERROR:root:The following gene can not be converted to an Ensembl ID: HST2508
# ERROR:root:The following gene can not be converted to an Ensembl ID: K2P12.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: OLD-35
# ERROR:root:The following gene can not be converted to an Ensembl ID: P47PHOX
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HALPG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: TILZ4B
# ERROR:root:The following gene can not be converted to an Ensembl ID: HKCA4
# ERROR:root:The following gene can not be converted to an Ensembl ID: MTRF1A
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: P56DOK-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA145E8.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BHLHA23
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P.11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDC-STAMP
# ERROR:root:The following gene can not be converted to an Ensembl ID: CGK
# ERROR:root:The following gene can not be converted to an Ensembl ID: 5-OPASE
# ERROR:root:The following gene can not be converted to an Ensembl ID: MI-ER2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSP56
# ERROR:root:The following gene can not be converted to an Ensembl ID: GSD1D
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCARD9
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCCCAP
# ERROR:root:The following gene can not be converted to an Ensembl ID: NACH6
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLIT-2
# ERROR:root:The following gene can not be converted to an Ensembl ID: C/EBP-ALPHA
# ERROR:root:The following gene can not be converted to an Ensembl ID: TESR
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGC45800
# ERROR:root:The following gene can not be converted to an Ensembl ID: C17DUPQ12
# ERROR:root:The following gene can not be converted to an Ensembl ID: PI-TP-BETA
# ERROR:root:The following gene can not be converted to an Ensembl ID: APO-AII
# ERROR:root:The following gene can not be converted to an Ensembl ID: P70-S6K
# ERROR:root:The following gene can not be converted to an Ensembl ID: H2-BF
# ERROR:root:The following gene can not be converted to an Ensembl ID: BA145L22
# ERROR:root:The following gene can not be converted to an Ensembl ID: G18.1A
# ERROR:root:The following gene can not be converted to an Ensembl ID: CN-III
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP15Q
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1043E3.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ955L16.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSA-MIR-588
# ERROR:root:The following gene can not be converted to an Ensembl ID: BK286B10
# ERROR:root:The following gene can not be converted to an Ensembl ID: C-ABL
# ERROR:root:The following gene can not be converted to an Ensembl ID: PLC-ETA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: METAP1L
# ERROR:root:The following gene can not be converted to an Ensembl ID: DJ1007G16.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: NBLA00052
# ERROR:root:The following gene can not be converted to an Ensembl ID: LY78
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP2CM
# ERROR:root:The following gene can not be converted to an Ensembl ID: HCGP-39
# ERROR:root:The following gene can not be converted to an Ensembl ID: CI-75KD
# ERROR:root:The following gene can not be converted to an Ensembl ID: BZX
# ERROR:root:The following gene can not be converted to an Ensembl ID: T-BET
#      GENE                           DISEASE   DISEASE_ID SCORE SOURCE  \
# 0     A2M  Alpha 2 macroglobulin deficiency  OMIM:614036  0.25   OMIM
# 0    A2MD  Alpha 2 macroglobulin deficiency  OMIM:614036  0.25   OMIM
# 0  CPAMD5  Alpha 2 macroglobulin deficiency  OMIM:614036  0.25   OMIM
# 0  FWP007  Alpha 2 macroglobulin deficiency  OMIM:614036  0.25   OMIM
# 0  S863-7  Alpha 2 macroglobulin deficiency  OMIM:614036  0.25   OMIM
#
#       GENE_ensembl GENE_mapping_status
# 0  ENSG00000175899   mapped to ensembl
# 0  ENSG00000175899   mapped to ensembl
# 0  ENSG00000175899   mapped to ensembl
# 0  ENSG00000175899   mapped to ensembl
# 0  ENSG00000175899   mapped to ensembl

# %%
gene_dx_formatted = gene_dx.sort_values('GENE').filter(['GENE_ensembl', 'DISEASE', 'DISEASE_ID', 'SCORE', 'SOURCE'])\
    .groupby(['DISEASE', 'DISEASE_ID', 'SCORE', 'SOURCE'], sort=False)['GENE_ensembl'].apply(list).reset_index()
gene_dx_formatted['GENE_ensembl'] = gene_dx_formatted['GENE_ensembl'].apply(lambda x: list(set([str(i) for i in x]))) #doing this to include null in list
gene_dx_formatted['GENE_ensembl'] = gene_dx_formatted['GENE_ensembl'].str.join(', ')
gene_dx_formatted.head()
# Out:
#                                              DISEASE       DISEASE_ID  \
# 0                                         Fibrinogen  PUBMED:20031577
# 1  Thiazide induced adverse metabolic effects in ...  PUBMED:23400010
# 2                             Personality dimensions  PUBMED:23903073
# 3  Autosomal dominant progressive external ophtha...  ORPHANET:254892
# 4            Mitochondrial DNA depletion syndrome 12      OMIM:615418
#
#                SCORE    SOURCE  \
# 0      0.24999999998      GWAS
# 1           0.249999      GWAS
# 2        0.249999825      GWAS
# 3  0.857142857142857  ORPHANET
# 4                  1      OMIM
#
#                                         GENE_ensembl
# 0           ENSG00000109065, ENSG00000109062,  HNATL
# 1  GLUN2A, ENSG00000183454, ENSG00000019144, ENSG...
# 2  GAL-NAC6S, ENSG00000121410, ST3GALA, ST3GALIA,...
# 3  ENSG00000171428, ENSG00000121410, ENSG00000110...
# 4  ENSG00000171428, ENSG00000121410, ENSG00000110...

# %%
hpoa_phen_genes_2015 = preprocessor.map_genes(hpoa_phen_genes_2015, ['GENE_LIST'])
print(len(hpoa_phen_genes_2015))
hpoa_phen_genes_2015.head()
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: ITS
# 276162
#        HPO_ID          HPO_NAME GENE_LIST HPO_ID_2019 GENE_LIST_ensembl  \
# 0  HP:0000878  11 pairs of ribs     HDAC6  HP:0000878   ENSG00000094631
# 0  HP:0000878  11 pairs of ribs       LBR  HP:0000878   ENSG00000143815
# 0  HP:0000878  11 pairs of ribs      SOX9  HP:0000878   ENSG00000125398
# 0  HP:0000878  11 pairs of ribs  RNU4ATAC  HP:0000878   ENSG00000264229
# 0  HP:0000878  11 pairs of ribs       ATR  HP:0000878   ENSG00000175054
#
#   GENE_LIST_mapping_status
# 0        mapped to ensembl
# 0        mapped to ensembl
# 0        mapped to ensembl
# 0        mapped to ensembl
# 0        mapped to ensembl

# %%
hpoa_phen_genes_2015_formatted = hpoa_phen_genes_2015.filter(['HPO_ID_2019','HPO_NAME','GENE_LIST_ensembl'])\
    .groupby(['HPO_ID_2019', 'HPO_NAME'], sort=False)['GENE_LIST_ensembl'].apply(list).reset_index()
hpoa_phen_genes_2015_formatted['GENE_LIST_ensembl'] = hpoa_phen_genes_2015_formatted['GENE_LIST_ensembl'].apply(lambda x: list(set([str(i) for i in x]))) #doing this to include null in list
hpoa_phen_genes_2015_formatted['GENE_LIST_ensembl'] = hpoa_phen_genes_2015_formatted['GENE_LIST_ensembl'].str.join(',')
hpoa_phen_genes_2015_formatted.head()
# Out:
#   HPO_ID_2019                                  HPO_NAME  \
# 0  HP:0000878                          11 pairs of ribs
# 1  HP:0001459                        1-3 toe syndactyly
# 2  HP:0006088  1-5 finger complete cutaneous syndactyly
# 3  HP:0010708                     1-5 finger syndactyly
# 4  HP:0010713                        1-5 toe syndactyly
#
#                                    GENE_LIST_ensembl
# 0  ENSG00000143815,ENSG00000264229,ENSG0000009463...
# 1                                    ENSG00000106571
# 2                                    ENSG00000105983
# 3                                    ENSG00000105983
# 4                                    ENSG00000106571

# %%
genecards = preprocessor.map_genes(genecards, ['GENE_ID'])
genecards.head()

# %%
disgenet = preprocessor.map_genes(disgenet, ['GENE_ID'])
disgenet.head()

# %%
orphanet = preprocessor.map_genes(orphanet, ['GENE'])
orphanet.head()

# %%
# 2015 KG
clinvar = preprocessor.map_genes(clinvar, ['GENE'])
clinvar.head()

# %%
gwas = preprocessor.map_genes(gwas, ['GENE'])
gwas.head()

# %%
gad = preprocessor.map_genes(gad, ['GENE_ID'])
gad.head()

# %%
gene_reviews = preprocessor.map_genes(gene_reviews, ['GENE'])
gene_reviews.head()

# %%
protein_interaction = preprocessor.map_genes(protein_interaction, ['PROTEIN_1', 'PROTEIN_2'])
protein_interaction.head()

# %%
biosystem = preprocessor.map_genes(biosystem, ['GENE'])
biosystem.head()

# %%
coba = preprocessor.map_genes(coba, ['GENE_ID'])
coba.head()

# %%
hgnc = preprocessor.map_genes(hgnc, ['GENE'])

hgnc.head()

# %%
mentha = preprocessor.map_genes(mentha, ['Gene A', 'Gene B'])

mentha.head()

# %%
transcription = preprocessor.map_genes(transcription, ['TF', 'TG'])
transcription.head()

# %%
omim_gene_dx = preprocessor.map_genes(omim_gene_dx, ['GENE'])
omim_gene_dx.head()
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDAN4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DER22t11-22
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRABIN
# ERROR:root:The following gene can not be converted to an Ensembl ID: FSHD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: Zmpste24
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRTS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MICRODEL3q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10Q26
# ERROR:root:The following gene can not be converted to an Ensembl ID: MSL1V1
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVC10
# ERROR:root:The following gene can not be converted to an Ensembl ID: PDE11A3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL5Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2q31
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ALS14
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHFL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: AVSD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT32
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD5
# ERROR:root:The following gene can not be converted to an Ensembl ID: KLOTHO
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVC7
# ERROR:root:The following gene can not be converted to an Ensembl ID: RP68
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL22Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6PTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2p16.1-p15
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBD13
# ERROR:root:The following gene can not be converted to an Ensembl ID: COOKL
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBMPFD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: 3H11AG
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOP4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CFEOM3C
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: KTCNCT
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPMRS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: VEL
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q15.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: TPDS
# ERROR:root:The following gene can not be converted to an Ensembl ID: LCA17
# ERROR:root:The following gene can not be converted to an Ensembl ID: MOCODA
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1P36
# ERROR:root:The following gene can not be converted to an Ensembl ID: CLCs
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL18P
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRD13
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBD17
# ERROR:root:The following gene can not be converted to an Ensembl ID: PETA3
# ERROR:root:The following gene can not be converted to an Ensembl ID: Mrtfa
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6pter
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA0624
# ERROR:root:The following gene can not be converted to an Ensembl ID: pre-mod(mdg4)-U
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIZUNA
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1179
# ERROR:root:The following gene can not be converted to an Ensembl ID: NEM9
# ERROR:root:The following gene can not be converted to an Ensembl ID: HRAD54
# ERROR:root:The following gene can not be converted to an Ensembl ID: MVCD3
# ERROR:root:The following gene can not be converted to an Ensembl ID: C10DELq23
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK4
# ERROR:root:The following gene can not be converted to an Ensembl ID: ATOH5
# ERROR:root:The following gene can not be converted to an Ensembl ID: FGQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP22q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGR4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSAN2B
# ERROR:root:The following gene can not be converted to an Ensembl ID: GLYCTK1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPHS10
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXQ21
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17Q23.1Q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP7Q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11p15p14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DER22t8-22
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ00289
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16p13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME3
# ERROR:root:The following gene can not be converted to an Ensembl ID: HYC
# ERROR:root:The following gene can not be converted to an Ensembl ID: PHP1C
# ERROR:root:The following gene can not be converted to an Ensembl ID: ANALBA
# ERROR:root:The following gene can not be converted to an Ensembl ID: LEPQTL1
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA0031
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT30
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL9p24.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1526
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT36
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPENCDI
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMT20
# ERROR:root:The following gene can not be converted to an Ensembl ID: JAE
# ERROR:root:The following gene can not be converted to an Ensembl ID: CANDF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q15.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CLLS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Chrna4
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPE7
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBD14
# ERROR:root:The following gene can not be converted to an Ensembl ID: C16DELQ22
# ERROR:root:The following gene can not be converted to an Ensembl ID: SF3B49
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8q12q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1q43q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6q11q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: ST3GALV
# ERROR:root:The following gene can not be converted to an Ensembl ID: HMN7B
# ERROR:root:The following gene can not be converted to an Ensembl ID: WAGRO
# ERROR:root:The following gene can not be converted to an Ensembl ID: EOE1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17q21.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1P32P31
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDPD
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q26qter
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q23.1Q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: C9DELp24.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXQ27.3Q28
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11p13
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCKL8
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: HJUMPY
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXq27.3q28
# ERROR:root:The following gene can not be converted to an Ensembl ID: AIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL9p
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUH1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP8Q22.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP21
# ERROR:root:The following gene can not be converted to an Ensembl ID: HYPT10
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDGII
# ERROR:root:The following gene can not be converted to an Ensembl ID: CHNG3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CFSMR
# ERROR:root:The following gene can not be converted to an Ensembl ID: IRHOM2
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA01613
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL7q11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP5P13
# ERROR:root:The following gene can not be converted to an Ensembl ID: KTWS
# ERROR:root:The following gene can not be converted to an Ensembl ID: SIDDT
# ERROR:root:The following gene can not be converted to an Ensembl ID: 3M2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP22.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: ECT
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL7Q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: AURORA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MRXHF1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT24
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXq28
# ERROR:root:The following gene can not be converted to an Ensembl ID: MEGDEL
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRIASS
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT35
# ERROR:root:The following gene can not be converted to an Ensembl ID: FEOM4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYQ11
# ERROR:root:The following gene can not be converted to an Ensembl ID: AUTS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT25
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: AOMS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: sens
# ERROR:root:The following gene can not be converted to an Ensembl ID: NKP30
# ERROR:root:The following gene can not be converted to an Ensembl ID: MUNC13-4
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ18
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP22q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: AFA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8q21.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: NMLFS
# ERROR:root:The following gene can not be converted to an Ensembl ID: AMMEC
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCLDS
# ERROR:root:The following gene can not be converted to an Ensembl ID: CELIAC6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19q13.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEOA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: HMNJ
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHFLD3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1757
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6q24q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: C17DELp13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP3q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: MDLS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q12Q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLSM7
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMD1CC
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3PTERP25
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1p32p31
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1150
# ERROR:root:The following gene can not be converted to an Ensembl ID: SPDA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: AUTS10
# ERROR:root:The following gene can not be converted to an Ensembl ID: D83198
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1017
# ERROR:root:The following gene can not be converted to an Ensembl ID: CELIAC5
# ERROR:root:The following gene can not be converted to an Ensembl ID: MDDGA3
# ERROR:root:The following gene can not be converted to an Ensembl ID: SRTD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYq11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXp11.23p11.22
# ERROR:root:The following gene can not be converted to an Ensembl ID: SCPNK
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK6
# ERROR:root:The following gene can not be converted to an Ensembl ID: FMTLE
# ERROR:root:The following gene can not be converted to an Ensembl ID: ACSTD1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYMY4
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLH2
# ERROR:root:The following gene can not be converted to an Ensembl ID: OTDD
# ERROR:root:The following gene can not be converted to an Ensembl ID: CHNG4
# ERROR:root:The following gene can not be converted to an Ensembl ID: OPHLC
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1872
# ERROR:root:The following gene can not be converted to an Ensembl ID: MICRODUP3q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL8Q21.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP5p13
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIEE7
# ERROR:root:The following gene can not be converted to an Ensembl ID: FBX38
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUH3
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT37
# ERROR:root:The following gene can not be converted to an Ensembl ID: OBX
# ERROR:root:The following gene can not be converted to an Ensembl ID: HANAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: NAOFEN
# ERROR:root:The following gene can not be converted to an Ensembl ID: HLD6
# ERROR:root:The following gene can not be converted to an Ensembl ID: ENSBTAG00000025302
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19P13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: IPLA2
# ERROR:root:The following gene can not be converted to an Ensembl ID: ITS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6Q24Q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL6Q11Q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: EJA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: HTGH
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16p12.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: CMD1BB
# ERROR:root:The following gene can not be converted to an Ensembl ID: DA10
# ERROR:root:The following gene can not be converted to an Ensembl ID: CUP2q35
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1756
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16p12.1p11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: NMLFS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXQ28
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEE4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19p13.13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q24
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL7q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUPXP11.23P11.22
# ERROR:root:The following gene can not be converted to an Ensembl ID: PKS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3pterp25
# ERROR:root:The following gene can not be converted to an Ensembl ID: PR46B
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2p21
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17P13.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: COXPD3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL4q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDLCQ14
# ERROR:root:The following gene can not be converted to an Ensembl ID: GRM1A
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11P13
# ERROR:root:The following gene can not be converted to an Ensembl ID: FAME4
# ERROR:root:The following gene can not be converted to an Ensembl ID: Gnas
# ERROR:root:The following gene can not be converted to an Ensembl ID: BBIS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL4Q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: NBPHOX
# ERROR:root:The following gene can not be converted to an Ensembl ID: Pde11a
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q25
# ERROR:root:The following gene can not be converted to an Ensembl ID: C7DELq11
# ERROR:root:The following gene can not be converted to an Ensembl ID: BRWS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: RHDA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ20974
# ERROR:root:The following gene can not be converted to an Ensembl ID: IH
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVD12
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL14Q11Q22
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10q23
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P12.1P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: MMEP
# ERROR:root:The following gene can not be converted to an Ensembl ID: HH12
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17q23.1q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP2q31.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: MLSM7
# ERROR:root:The following gene can not be converted to an Ensembl ID: BMIQ16
# ERROR:root:The following gene can not be converted to an Ensembl ID: DBA6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q21.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL18p
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASL13
# ERROR:root:The following gene can not be converted to an Ensembl ID: HNPCC6
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2p12p11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: STHAG2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PMGYS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP8q22.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: KBGS
# ERROR:root:The following gene can not be converted to an Ensembl ID: ADIPQTL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASD9
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT26
# ERROR:root:The following gene can not be converted to an Ensembl ID: HBFQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD2
# ERROR:root:The following gene can not be converted to an Ensembl ID: LPSA
# ERROR:root:The following gene can not be converted to an Ensembl ID: ADIPQTL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: GAY1
# ERROR:root:The following gene can not be converted to an Ensembl ID: SHORT
# ERROR:root:The following gene can not be converted to an Ensembl ID: MDDGC3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL18q
# ERROR:root:The following gene can not be converted to an Ensembl ID: HDL3
# ERROR:root:The following gene can not be converted to an Ensembl ID: MDDGB3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP22Q13
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: GRDX
# ERROR:root:The following gene can not be converted to an Ensembl ID: IBD28
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P16.1-P15
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ10583
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL13q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL19Q13.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXq21
# ERROR:root:The following gene can not be converted to an Ensembl ID: PCH10
# ERROR:root:The following gene can not be converted to an Ensembl ID: FDAH
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP18pDEL18q
# ERROR:root:The following gene can not be converted to an Ensembl ID: OTDD
# ERROR:root:The following gene can not be converted to an Ensembl ID: PLSA1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17p13.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP18PDEL18Q
# ERROR:root:The following gene can not be converted to an Ensembl ID: DHMN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: NPTIIC
# ERROR:root:The following gene can not be converted to an Ensembl ID: FSAP35
# ERROR:root:The following gene can not be converted to an Ensembl ID: TEMTYS
# ERROR:root:The following gene can not be converted to an Ensembl ID: NIDDM
# ERROR:root:The following gene can not be converted to an Ensembl ID: ASPRS. LBSL
# ERROR:root:The following gene can not be converted to an Ensembl ID: CFEOM3B
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL13Q14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1q41q42
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL22q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PACHD
# ERROR:root:The following gene can not be converted to an Ensembl ID: HPCX1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P21
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS4
# ERROR:root:The following gene can not be converted to an Ensembl ID: SRXY4
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP17Q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: CAE3
# ERROR:root:The following gene can not be converted to an Ensembl ID: ARVD10
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL10q26
# ERROR:root:The following gene can not be converted to an Ensembl ID: FGQTL6
# ERROR:root:The following gene can not be converted to an Ensembl ID: TIIAC
# ERROR:root:The following gene can not be converted to an Ensembl ID: HSAN
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1p36
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL11P15P14
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3Q13.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: PDE11A2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDG1A
# ERROR:root:The following gene can not be converted to an Ensembl ID: CTRCT28
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP2Q31.1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3q29
# ERROR:root:The following gene can not be converted to an Ensembl ID: GNASAS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELYQ11
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: CD40BP
# ERROR:root:The following gene can not be converted to an Ensembl ID: EIEE4
# ERROR:root:The following gene can not be converted to an Ensembl ID: BCPR
# ERROR:root:The following gene can not be converted to an Ensembl ID: MICRODEL15q13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: SF3B155
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL9q34
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL5q12
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q41Q42
# ERROR:root:The following gene can not be converted to an Ensembl ID: MGC4067
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15q24
# ERROR:root:The following gene can not be converted to an Ensembl ID: AMMEC
# ERROR:root:The following gene can not be converted to an Ensembl ID: FRIASS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP7q11.23
# ERROR:root:The following gene can not be converted to an Ensembl ID: OGS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: FLJ90130
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXp21
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL1Q43Q44
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL15Q26QTER
# ERROR:root:The following gene can not be converted to an Ensembl ID: MCOPCB7
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXp22.11
# ERROR:root:The following gene can not be converted to an Ensembl ID: ETL2
# ERROR:root:The following gene can not be converted to an Ensembl ID: Arsg
# ERROR:root:The following gene can not be converted to an Ensembl ID: SIOD
# ERROR:root:The following gene can not be converted to an Ensembl ID: DELXP11.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: RFH1
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1633
# ERROR:root:The following gene can not be converted to an Ensembl ID: POREN1
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFNS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL9P
# ERROR:root:The following gene can not be converted to an Ensembl ID: Kcnv2
# ERROR:root:The following gene can not be converted to an Ensembl ID: IHPS
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17q11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17p13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL3q13.31
# ERROR:root:The following gene can not be converted to an Ensembl ID: BFIS1
# ERROR:root:The following gene can not be converted to an Ensembl ID: FECD7
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL16p13.3
# ERROR:root:The following gene can not be converted to an Ensembl ID: OPHLC
# ERROR:root:The following gene can not be converted to an Ensembl ID: C16DELq22
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRIP4q32.1q32.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HALP2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL17q23.1q23.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PEOA5
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP1q21
# ERROR:root:The following gene can not be converted to an Ensembl ID: PTOS2
# ERROR:root:The following gene can not be converted to an Ensembl ID: HYPT5
# ERROR:root:The following gene can not be converted to an Ensembl ID: DDD4
# ERROR:root:The following gene can not be converted to an Ensembl ID: CDW108
# ERROR:root:The following gene can not be converted to an Ensembl ID: MYMY5
# ERROR:root:The following gene can not be converted to an Ensembl ID: AAT6
# ERROR:root:The following gene can not be converted to an Ensembl ID: POROK5
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL14q11q22
# ERROR:root:The following gene can not be converted to an Ensembl ID: CUP2Q35
# ERROR:root:The following gene can not be converted to an Ensembl ID: TRIP4Q32.1Q32.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: PP2CM
# ERROR:root:The following gene can not be converted to an Ensembl ID: CUP2Q35
# ERROR:root:The following gene can not be converted to an Ensembl ID: NESP4
# ERROR:root:The following gene can not be converted to an Ensembl ID: KIAA1204
# ERROR:root:The following gene can not be converted to an Ensembl ID: HHT3
# ERROR:root:The following gene can not be converted to an Ensembl ID: DEL2P12P11.2
# ERROR:root:The following gene can not be converted to an Ensembl ID: DUP1Q21
#      GENE                                DISEASE MIM_NUMBER SOURCE_CODE  \
# 0     A2M       Alpha-2-macroglobulin deficiency     614036           C
# 0    A2MD       Alpha-2-macroglobulin deficiency     614036           C
# 1     A2M   Alzheimer disease, susceptibility to     104300           C
# 1    A2MD   Alzheimer disease, susceptibility to     104300           C
# 2  A4GALT  Blood group, P1Pk system, p phenotype     111400           P
#
#   LINGKAGE_INFO     GENE_ensembl GENE_mapping_status
# 0             1  ENSG00000175899   mapped to ensembl
# 0             1  ENSG00000175899   mapped to ensembl
# 1             3  ENSG00000175899   mapped to ensembl
# 1             3  ENSG00000175899   mapped to ensembl
# 2             3  ENSG00000128274   mapped to ensembl

# %%
omim_gene_dx_formatted = omim_gene_dx.filter(['GENE_ensembl', 'DISEASE', 'MIM_NUMBER', 'SOURCE_CODE', 'LINGKAGE_INFO'])\
    .groupby(['DISEASE', 'MIM_NUMBER', 'SOURCE_CODE', 'LINGKAGE_INFO'], sort=False)['GENE_ensembl'].apply(list).reset_index()
omim_gene_dx_formatted['GENE_ensembl'] = omim_gene_dx_formatted['GENE_ensembl'].apply(lambda x: list(set([str(i) for i in x]))) #doing this to include null in list
omim_gene_dx_formatted['GENE_ensembl'] = omim_gene_dx_formatted['GENE_ensembl'].str.join(', ')
omim_gene_dx_formatted.head()
# Out:
#                                   DISEASE MIM_NUMBER SOURCE_CODE  \
# 0        Alpha-2-macroglobulin deficiency     614036           C
# 1    Alzheimer disease, susceptibility to     104300           C
# 2   Blood group, P1Pk system, p phenotype     111400           P
# 3   Blood group, P1Pk system, P phenotype     111400           P
# 4          NOR polyagglutination syndrome     111400           P
#
#   LINGKAGE_INFO                                       GENE_ensembl
# 0             1                                    ENSG00000175899
# 1             3  ENSG00000010704,ENSG00000175899,MVCD3,ENSG0000...
# 2             3                                    ENSG00000128274
# 3             3                                    ENSG00000128274
# 4             3                                    ENSG00000128274

# %% [markdown]
# # Write 2015 Phenolyzer KG edges to file

# %%
hpoa_phen_genes_2015_formatted \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COMPILED_HPO_PHENOTYPE_GENE', sep='\t', index=False, header=False)

# %%
gene_dx_formatted.sort_values('DISEASE').filter(['GENE_ensembl', 'DISEASE', 'DISEASE_ID', 'SCORE', 'SOURCE'])\
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COMPILED_GENE_DISEASE_SCORE', sep='\t', index=False)

# %%
with open(str(PHENOLYZER_2015_OUTPUT_DIR / 'DB_HUMAN_GENE_ID'), 'w') as f:
    f.write('#Format: tax_id GeneID Symbol LocusTag Synonyms dbXrefs chromosome map_location description type_of_gene Symbol_from_nomenclature_authority Full_name_from_nomenclature_authority Nomenclature_status Other_designations Modification_date (tab is used as a separator, pound sign - start of a comment)\n')
    human_gene_id_format.sort_values('').to_csv(f, sep='\t', index=False, header=False)

# %%
omim_gene_dx.filter(['GENE_ensembl', 'DISEASE', 'MIM_NUMBER', 'SOURCE_CODE', 'LINGKAGE_INFO']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_OMIM_GENE_DISEASE', sep='\t', index=False)

# %%
transcription.filter(['TF_ensembl', 'TG_ensembl', 'EVIDENCE', 'PUBMED', 'SCORE']) \
    .rename(columns={'TF_ensembl':'TF', 'TG_ensembl':'TG'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_HTRI_TRANSCRIPTION_INTERACTION', sep='\t', index=False)

# %%
mentha.filter(['Gene A_ensembl', 'Gene B_ensembl', 'EVIDENCE', 'Score', 'PMID']) \
    .rename(columns={'Gene A_ensembl':'Gene A', 'Gene B_ensembl':'Gene B'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_MENTHA_GENE_GENE_INTERACTION', sep='\t', index=False)

# %%
hgnc.filter(['GENE_ensembl', 'GENE_FAMILY_TAG', 'DESCRIPTION']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_HGNC_GENE_FAMILY', sep='\t', index=False)

# %%
coba.filter(['GENE_ID_ensembl', 'DISEASE', 'SOURCE', 'SCORE', 'CATEGORY']) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COBA_NEUROCOMPLEX', sep='\t', index=False, header=False)

# %%
biosystem.filter(['BIOSYSTEM_ID', 'GENE_ensembl', 'SCORE', 'NAME']) \
    .rename(columns={'GENE_ensembl': 'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COMPILED_BIOSYSTEM_SCORE', sep='\t', index=False)

# %%
protein_interaction.filter(['PROTEIN_1_ensembl', 'PROTEIN_2_ensembl', 'EVIDENCE', 'SCORE', 'PUBMED_ID']) \
    .rename(columns={'PROTEIN_1_ensembl':'PROTEIN_1', 'PROTEIN_2_ensembl':'PROTEIN_2'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COMPILED_BINARY_PROTEIN_INTERACTION_SCORE', sep='\t',  index=False)

# %%
gene_reviews.filter(['GENE_ensembl', 'DISEASE', 'OMIM_NUMBER']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_COMPILED_GENEREVIEWS', sep='\t', index=False)

# %%
genecards.filter(['GENE_ID_ensembl', 'DISEASE', 'UNK', 'SCORE', 'SOURCE']) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_GENECARDS_GENE_DISEASE_SCORE', sep='\t', index=False, header=False)

# %%
gad.filter(['GENE_ID_ensembl', 'DISEASE', 'DISEASE_PUBMED', 'SCORE', 'SOURCE']) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_GAD_GENE_DISEASE_SCORE', sep='\t', index=False, header=False)

# %%
disgenet.filter(['GENE_ID_ensembl', 'DISEASE', 'DISEASE_ID', 'SCORE', 'SOURCE']) \
    .rename(columns={'GENE_ID_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_DISGENET_GENE_DISEASE_SCORE', sep='\t', index=False, header=False)

# %%
orphanet.filter(['GENE_ensembl', 'DISEASE', 'ORPHANET_NUMBER', 'SOURCE_COUNT', 'LINKAGE_INFO']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_ORPHANET_GENE_DISEASE', sep='\t', index=False)

# %%
gwas.filter(['GENE_ensembl', 'DISEASE', 'PUBMED_NUMBER', 'RAW_SCORE']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_GWAS_GENE_DISEASE', sep='\t', index=False)

# %%
clinvar.filter(['GENE_ensembl', 'DISEASE', 'MIM_NUMBER', 'SOURCE_COUNT']) \
    .rename(columns={'GENE_ensembl':'GENE'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_CLINVAR_GENE_DISEASE', sep='\t', index=False)

# %%
# write 2015 KG
hpoa_phen_diseases_2015.filter(['HPO_ID_2019', 'SOURCE', 'HPO_DISEASE_NAME', 'FREQUENCY']) \
    .rename(columns={'HPO_ID_2019':'HPO_ID'}) \
    .to_csv(PHENOLYZER_2015_OUTPUT_DIR / 'DB_HPO_ANNOTATION', sep='\t', index=False)

# %% [markdown]
# # Convert Noisy Phenotype Frequencies to 2019 HPO

# %%
hpo_infant = preprocessor.map_phenotypes(hpo_infant, col_name = 'HPO')
hpo_child = preprocessor.map_phenotypes(hpo_child,col_name = 'HPO')
hpo_adolescent = preprocessor.map_phenotypes(hpo_adolescent, col_name = 'HPO')
hpo_adult = preprocessor.map_phenotypes(hpo_adult, col_name = 'HPO')
hpo_elderly = preprocessor.map_phenotypes(hpo_elderly, col_name = 'HPO')

# %%
def rename_cols(df):
    return df.drop(columns=['HPO']).rename(columns={'HPO_ID_2019':'HPO'})

# %%
hpo_infant = rename_cols(hpo_infant)
hpo_infant.to_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Infants_normalized.tsv", sep = "\t", index=False)

# %%
hpo_child = rename_cols(hpo_child)
hpo_child.to_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Children_normalized.tsv", sep = "\t", index=False)

hpo_adolescent = rename_cols(hpo_adolescent)
hpo_adolescent.to_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Adolescent_normalized.tsv", sep = "\t", index=False)

hpo_adult = rename_cols(hpo_adult)
hpo_adult.to_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Adult_normalized.tsv", sep = "\t", index=False)

hpo_elderly = rename_cols(hpo_elderly)
hpo_elderly.to_csv(config.CLAIMS_PATH / "HPO_Pheno_Counts_Elderly_normalized.tsv", sep = "\t", index=False)

# %% [markdown]
# # Convert 2019 Disegenet & HPOA (used for finding non-disease genes in simulation pipeline) to Ensembl

# %% [markdown]
# ## Read in data

# %%
disegenet_mappings = pd.read_csv(config.DISGENET_PATH /'source'/ "disease_mappings.tsv", delimiter="|")
disegenet_mappings_hpo = disegenet_mappings.query("vocabulary == 'HPO'")

# %%
disegenet_pheno_full = pd.read_csv(config.DISGENET_PATH / 'source' /"all_gene_disease_associations.tsv", delimiter="\t")

hpoa_genes_phenotypes = pd.read_csv(config.HPO_PATH / "ALL_SOURCES_ALL_FREQUENCIES_diseases_to_genes_to_phenotypes.txt",
                                        delimiter= "\t",
                                        names = ['DiseaseID', "GeneID", "Gene_Symbol",  "HPO_ID", "HPO_Name"],
                                       skiprows=1, dtype=str)


fp_genes_prob = pd.read_csv(config.FLAGS_PATH / "flags_s3_fp_genes_freqs.txt", \
                            delimiter="\t", names=["GeneSymbol","Count"])

date_to_gene_map = {'01-Dec': 'DEC1', '06-Sep': 'SEPT6', '09-Mar': 'MARCH9',  '09-Sep': 'SEPT9', '11-Mar': 'MARCH11', 
                   '02-Sep': 'SEPT2', '01-Mar': 'MARCH1','10-Sep': 'SEPT10', '05-Mar': 'MARCH5', '07-Mar': 'MARCH7',
                   '11-Sep': 'SEPT11', '02-Mar': 'MARCH2', '07-Sep': 'SEPT7', '12-Sep': 'SEPT12', '04-Mar': 'MARCH4',
                   '15-Sep': 'SEP15', '08-Mar': 'MARCH8', '03-Sep': 'SEPT3', '05-Sep': 'SEPT5', '08-Sep': 'SEPT8',
                   '06-Mar': 'MARCH6', '01-Sep': 'SEPT1','03-Mar': 'MARCH3','14-Sep': 'SEPT14','10-Mar': 'MARCH10'}
fp_genes_prob['GeneSymbol'] = fp_genes_prob['GeneSymbol'].replace(date_to_gene_map)

# %% [markdown]
# ## perform mapping

# %%
fp_genes_prob = preprocessor.map_genes(fp_genes_prob, ['GeneSymbol'])

# %%
disegenet_mappings_hpo = disegenet_mappings_hpo.rename(columns={'code': 'HPO_ID'})
disegenet_mappings_hpo = preprocessor.map_phenotypes(disegenet_mappings_hpo)

# %%
hpoa_genes_phenotypes = preprocessor.map_genes(hpoa_genes_phenotypes, ['Gene_Symbol'])
hpoa_genes_phenotypes = preprocessor.map_phenotypes(hpoa_genes_phenotypes)

# %%
disegenet_pheno_full = preprocessor.map_genes(disegenet_pheno_full, ['geneSymbol'])

# %% [markdown]
# ## write to file

# %%
disegenet_mappings_hpo = disegenet_mappings_hpo.drop(columns=['name', 'HPO_ID', 'vocabulary'])
disegenet_mappings_hpo.to_csv(config.DISGENET_PATH / "hpo_disease_mappings_normalized.tsv", sep = '\t')

# %%
disegenet_pheno_full = disegenet_pheno_full.rename(columns={'geneSymbol_ensembl': 'ensembl_ids' })
disegenet_pheno_full.to_csv(config.DISGENET_PATH / "all_gene_disease_associations_normalized.tsv", sep='\t')

# %%
hpoa_genes_phenotypes = hpoa_genes_phenotypes.rename(columns={'Gene_Symbol_ensembl': 'ensembl_ids'})
hpoa_genes_phenotypes.to_csv(config.HPO_PATH / "ALL_SOURCES_ALL_FREQUENCIES_diseases_to_genes_to_phenotypes_normalized.txt", sep='\t')

# %%
fp_genes_prob = fp_genes_prob.drop(columns=['GeneSymbol']).rename(columns={'GeneSymbol_ensembl':'Ensembl_ID'})
fp_genes_prob.to_csv(config.FLAGS_PATH / "flags_s3_fp_genes_freqs_normalized.txt", sep="\t")

# %% [markdown]
# # Convert Orphanet Data used for simulating patients to Ensembl & 2019 HPO

# %%
# NOTE: These files are created via the Orphanet Convert to Flat Files script
orphanet_phenotypes_2015 = pd.read_csv(config.ORPHANET_PATH / 'intermediate_files'/ 'orphanet_final_disease_hpo_2015.tsv', sep='\t', dtype=str)
orphanet_gene_metadata_2015 = pd.read_csv(config.ORPHANET_PATH / 'intermediate_files'/ 'orphanet_final_gene_metadata_2015.tsv', sep='\t', dtype=str)
orphanet_genes_2015 = pd.read_csv(config.ORPHANET_PATH / 'intermediate_files' / 'orphanet_final_disease_genes_2015_bugfix.tsv', sep='\t', dtype=str)
orphanet_disease_metadata_2015 = pd.read_csv(config.ORPHANET_PATH / 'intermediate_files' / 'orphanet_final_disease_metadata_2015_bugfix.tsv', sep='\t', dtype=str)

#Make sure all orphanet phenotypes are in HPO 2019 hierarchy
# First, drop rows with 'HP:0500014' (abnormal test result) because it doesn't map to 2019 HPO & isn't very useful
orphanet_phenotypes_2015 = orphanet_phenotypes_2015.loc[orphanet_phenotypes_2015['HPO_ID']  != 'HP:0500014']
orphanet_phenotypes_2015 = preprocessor.map_phenotypes(orphanet_phenotypes_2015)
orphanet_phenotypes_2015 = orphanet_phenotypes_2015.drop(columns=['HPO_ID']).rename(columns={'HPO_ID_2019': 'HPO_ID'})
assert all( p in hpo_2019.nodes() for p in orphanet_phenotypes_2015['HPO_ID'])

# %%
# convert all orphanet genes to Ensembl IDs
orphanet_genes_2015 = preprocessor.map_genes(orphanet_genes_2015, ['Gene_Symbol'])
orphanet_genes_2015 = orphanet_genes_2015.drop(columns=['Gene_Symbol']).rename(columns={'Gene_Symbol_ensembl': 'Ensembl_ID'})
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLC7A2-IT1

# %%
orphanet_gene_metadata_2015 = preprocessor.map_genes(orphanet_gene_metadata_2015, ['Gene_Symbol'])
orphanet_gene_metadata_2015 = orphanet_gene_metadata_2015.drop(columns=['Gene_Symbol']).rename(columns={'Gene_Symbol_ensembl': 'Ensembl_ID'})
# Out:
# ERROR:root:The following gene can not be converted to an Ensembl ID: SLC7A2-IT1

# %%
orphanet_genes_2015.loc[orphanet_genes_2015['Ensembl_ID'] == 'ENSG00000262919']
# Out:
# Empty DataFrame
# Columns: [OrphaNumber, Disorder_Name, DG_Assoc_First_Published_Post_2015_01, Ensembl_ID, Gene_Symbol_mapping_status]
# Index: []

# %%
orphanet_phenotypes_2015.to_csv(config.ORPHANET_PATH / 'orphanet_final_disease_hpo_normalized_2015.tsv', sep='\t', index=False)
orphanet_gene_metadata_2015.to_csv(config.ORPHANET_PATH / 'orphanet_final_gene_metadata_normalized_2015.tsv', sep='\t', index=False)
orphanet_genes_2015.to_csv(config.ORPHANET_PATH / 'orphanet_final_disease_genes_normalized_2015.tsv', sep='\t', index=False)
orphanet_disease_metadata_2015.to_csv(config.ORPHANET_PATH / 'orphanet_final_disease_metadata_normalized_2015.tsv', sep='\t', index=False)
